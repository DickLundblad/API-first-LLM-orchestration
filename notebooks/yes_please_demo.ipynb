# %% [markdown]
# # Import Required Libraries
# This section would normally import any necessary libraries, but for a simple print statement, no imports are required.

# %%
# Print a Friendly Message
print('Yes, please!')
